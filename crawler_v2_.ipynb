# %%
from selenium.webdriver.common.by import By
from selenium import webdriver as wd
from bs4 import BeautifulSoup as bs
from selenium.common.exceptions import ElementNotInteractableException
import time
import re


# 데이터 베이스
DataBase = []

# pin 데이터 변환 딕셔너리
pinReplacer = {
    "pin_general"    : "G",
    "pin_reserve"    : "R",
    "pin_generalDT"  : "DT",
    "pin_generalWT"  : "WT"
}

def parser(sido:str)->None:
    """
    Description
    -----------
    페이지의 html로부터 데이터를 dict 형태로 저장하고 DataBase list에 이를 적재함

    Parameters
    ----------
        - sido(str) : 시도 이름

    Returns --> None
    """
    try:
        htmlraw = driver.page_source
        soup = bs(htmlraw, "html5lib")
        lis = soup.select(".quickSearchResultBoxSidoGugun > li")
        for li in lis:
            tmp = {}
            location = li.select_one("p").text[:-9]
            tmp["지점면"] = li.select_one("strong").text.strip()
            tmp["주소"] = location
            tmp["시군구"] = loactionFilter(location)[0]
            tmp["시도"] = loactionFilter(location)[1]
            tmp["타입"] = pinReplacer[li.select_one("i").get_attribute_list("class")[0]]
            DataBase.append(tmp)
    except Exception as e:
        print(e)
        print("    ---> ",sido, "에러 발생")

def get_sidos():
    """
    Description
    -----------
    시도 이름 리스트 반환 함수

    Parameters : None

    Returns
    -------
    sidos(list) : 시도 리스트
    """
    htmlraw = driver.page_source
    soup = bs(htmlraw, "html5lib")
    sidos = list(map(lambda web : web.text ,soup.select(".sido_arae_box > li")))
    return sidos

def loactionFilter(location:str)->tuple:
    """
    Description
    -----------
    정규식을 이용하여 주소 데이터로부터 "도/시/군/구"를 추출하는 함수

    Parameters
    ----------
    location(str) : 주소 데이터

    Returns
    -------
    - sido, gugun (tuple)
        - 추출 된 주소 데이터가 [도, 시, 구, 군]일 때,
        - 리스트에서 첫번째 인자 --> sido
        - " ".join(나머지 인자들) --> gugun
    """
    pattern = re.compile(r"\s?([가-힣]+[도|시|구|군])\b")
    filtered = pattern.findall(location)
    if len(filtered) > 4:
        data = filtered[:3]
    else:
        data = filtered
    try: 
        sido = data[0]
        gugun = " ".join(data[1:])
    except IndexError:
        sido = "대구광역시" # 사이트 내부 주소누락 에러 처리
        gugun = '북구'
    return sido, gugun

def crawler()->None:
    """
    Description
    -----------
    시도 -> 전체 옵션을 반복적으로 크롤링하는 함수

    Parameters, Returns --> None
    """
    for i, sido in enumerate(get_sidos()):
        clickLocalSearch()
        time.sleep(1)
        sidoWebEle()[i].click()
        time.sleep(1)
        try:
            clickTotalOption()    
            time.sleep(8)
            parser(sido)
        except ElementNotInteractableException:
            parser(sido)
        except Exception as e:
            print(e)
            print(sido)

# 지역검색 옵션 클릭함수
clickLocalSearch = lambda : driver.find_element(By.CSS_SELECTOR, ".loca_search").click()

# 시도 내에 전체 클릭함수
clickTotalOption = lambda : driver.find_element(By.CSS_SELECTOR,".set_gugun_cd_btn").click()

# sido webelement list 반환함수
sidoWebEle = lambda : driver.find_elements(By.CSS_SELECTOR,".set_sido_cd_btn")

# %%
# 드라이버 열기
driver = wd.Chrome()
time.sleep(5)

# target url로 이동
targetUrl = "https://www.starbucks.co.kr/store/store_map.do"
driver.get(targetUrl)
time.sleep(5)

crawler()

driver.close()

# %%
print("전체 데이터 수 : ", len(DataBase))
DataBase[]
# Out:
# 전체 데이터 수 :  1904
# [{'지점면': '창원상남로  ',
#   '주소': '경상남도 창원시 성산구 상남로 88 (상남동)',
#   '시군구': '경상남도',
#   '시도': '창원시 성산구',
#   '타입': 'G'},
#  {'지점면': '마산역DT  ',
#   '주소': '경상남도 창원시 마산회원구 3·15대로 715 (석전동)',
#   '시군구': '경상남도',
#   '시도': '창원시 마산회원구',
#   '타입': 'DT'},
#  {'지점면': '마산해안대로DT  ',
#   '주소': '경상남도 창원시 마산합포구 해안대로 383 (오동동)',
#   '시군구': '경상남도',
#   '시도': '창원시 마산합포구',
#   '타입': 'DT'},
#  {'지점면': '진해자은DT  ',
#   '주소': '경상남도 창원시 진해구 진해대로 962 (자은동)',
#   '시군구': '경상남도',
#   '시도': '창원시 진해구',
#   '타입': 'DT'},
#  {'지점면': '창원역DT  ',
#   '주소': '경상남도 창원시 의창구 의창대로 68 (팔용동)',
#   '시군구': '경상남도',
#   '시도': '창원시 의창구',
#   '타입': 'DT'},
#  {'지점면': '창원호계DT  ',
#   '주소': '경상남도 창원시 마산회원구 내서읍 호원로 315 ',
#   '시군구': '경상남도',
#   '시도': '창원시 마산회원구',
#   '타입': 'DT'},
#  {'지점면': '창원마창대교  ',
#   '주소': '경상남도 창원시 성산구 삼귀로 159 (귀곡동)',
#   '시군구': '경상남도',
#   '시도': '창원시 성산구',
#   '타입': 'G'},
#  {'지점면': '삼성창원병원  ',
#   '주소': '경상남도 창원시 마산회원구 팔용로 158 (합성동)',
#   '시군구': '경상남도',
#   '시도': '창원시 마산회원구',
#   '타입': 'G'},
#  {'지점면': '마산터미널  ',
#   '주소': '경상남도 창원시 마산회원구 합성남로 6-1 (합성동)',
#   '시군구': '경상남도',
#   '시도': '창원시 마산회원구',
#   '타입': 'G'},
#  {'지점면': '진해용원  ',
#   '주소': '경상남도 창원시 진해구 안골로 336 (용원동) 형제빌딩',
#   '시군구': '경상남도',
#   '시도': '창원시 진해구',
#   '타입': 'G'},
#  {'지점면': '창원리베라  ',
#   '주소': '경상남도 창원시 성산구 중앙대로100번길 9 (상남동)',
#   '시군구': '경상남도',
#   '시도': '창원시 성산구',
#   '타입': 'G'},
#  {'지점면': '창원상남중앙  ',
#   '주소': '경상남도 창원시 성산구 마디미로 20 (상남동)',
#   '시군구': '경상남도',
#   '시도': '창원시 성산구',
#   '타입': 'G'},
#  {'지점면': '창원상남동R  ',
#   '주소': '경상남도 창원시 성산구 상남로 132 (상남동)',
#   '시군구': '경상남도',
#   '시도': '창원시 성산구',
#   '타입': 'R'},
#  {'지점면': '신세계마산  ',
#   '주소': '경상남도 창원시 마산합포구 합포로 251 (산호동) 신세계백화점 내 지하1층',
#   '시군구': '경상남도',
#   '시도': '창원시 마산합포구',
#   '타입': 'G'},
#  {'지점면': '창원시티세븐  ',
#   '주소': '경상남도 창원시 성산구 원이대로 320 (대원동)',
#   '시군구': '경상남도',
#   '시도': '창원시 성산구',
#   '타입': 'G'},
#  {'지점면': '경남대  ',
#   '주소': '경상남도 창원시 마산합포구 월영남로 3 (해운동)',
#   '시군구': '경상남도',
#   '시도': '창원시 마산합포구',
#   '타입': 'G'},
#  {'지점면': '창원용지호수  ',
#   '주소': '경상남도 창원시 성산구 용지로169번길 1 (용호동)',
#   '시군구': '경상남도',
#   '시도': '창원시 성산구',
#   '타입': 'G'},
#  {'지점면': '마산월남동DT  ',
#   '주소': '경상남도 창원시 마산합포구 3·15대로 70 (월남동2가)',
#   '시군구': '경상남도',
#   '시도': '창원시 마산합포구',
#   '타입': 'DT'},
#  {'지점면': '마산봉암로DT  ',
#   '주소': '경상남도 창원시 마산회원구 봉양로 118 (봉암동)',
#   '시군구': '경상남도',
#   '시도': '창원시 마산회원구',
#   '타입': 'DT'},
#  {'지점면': '진해경화역DT  ',
#   '주소': '경상남도 창원시 진해구 진해대로 698 (경화동)',
#   '시군구': '경상남도',
#   '시도': '창원시 진해구',
#   '타입': 'DT'},
#  {'지점면': '창원반림  ',
#   '주소': '경상남도 창원시 성산구 반송로 150 (반림동)',
#   '시군구': '경상남도',
#   '시도': '창원시 성산구',
#   '타입': 'G'},
#  {'지점면': '창원유니시티  ',
#   '주소': '경상남도 창원시 의창구 중동중앙로 47 (중동)',
#   '시군구': '경상남도',
#   '시도': '창원시 의창구',
#   '타입': 'G'},
#  {'지점면': '창원NC파크R  ',
#   '주소': '경상남도 창원시 마산회원구 삼호로 63 (양덕동), 창원NC파크',
#   '시군구': '경상남도',
#   '시도': '창원시 마산회원구',
#   '타입': 'R'},
#  {'지점면': '창원중앙역  ',
#   '주소': '경상남도 창원시 의창구 용동로 91 (사림동)',
#   '시군구': '경상남도',
#   '시도': '창원시 의창구',
#   '타입': 'G'},
#  {'지점면': '진해부산신항  ',
#   '주소': '경상남도 창원시 진해구 신항동로 121 (용원동) 112호',
#   '시군구': '경상남도',
#   '시도': '창원시 진해구',
#   '타입': 'G'},
#  {'지점면': '창원대로DT  ',
#   '주소': '경상남도 창원시 성산구 성산패총로 182 (가음정동)',
#   '시군구': '경상남도',
#   '시도': '창원시 성산구',
#   '타입': 'DT'},
#  {'지점면': '창원사파  ',
#   '주소': '경상남도 창원시 성산구 창이대로689번길 4-4 (사파동) 1,2층',
#   '시군구': '경상남도',
#   '시도': '창원시 성산구',
#   '타입': 'G'},
#  {'지점면': '진해장천  ',
#   '주소': '경상남도 창원시 진해구 충장로 662 (장천동), [108호, 109호, 110호, 111호]',
#   '시군구': '경상남도',
#   '시도': '창원시 진해구',
#   '타입': 'G'},
#  {'지점면': '창원파티마병원  ',
#   '주소': '경상남도 창원시 의창구 창이대로 45 (명서동)',
#   '시군구': '경상남도',
#   '시도': '창원시 의창구',
#   '타입': 'G'},
#  {'지점면': '창원내서  ',
#   '주소': '경상남도 창원시 마산회원구 내서읍 광려천서로 81 ',
#   '시군구': '경상남도',
#   '시도': '창원시 마산회원구',
#   '타입': 'G'},
#  {'지점면': '마산진동DT  ',
#   '주소': '경상남도 창원시 마산합포구 진동면 삼진의거대로 589-1 ',
#   '시군구': '경상남도',
#   '시도': '창원시 마산합포구',
#   '타입': 'DT'},
#  {'지점면': '통영이마트  ',
#   '주소': '경상남도 통영시 광도면 죽림4로 9 ',
#   '시군구': '경상남도',
#   '시도': '통영시',
#   '타입': 'G'},
#  {'지점면': '통영죽림  ',
#   '주소': '경상남도 통영시 광도면 죽림해안로 64-72 ',
#   '시군구': '경상남도',
#   '시도': '통영시',
#   '타입': 'G'},
#  {'지점면': '거제대로DT  ',
#   '주소': '경상남도 거제시 거제대로 4521 (수월동)',
#   '시군구': '경상남도',
#   '시도': '거제시',
#   '타입': 'DT'},
#  {'지점면': '거제고현  ',
#   '주소': '경상남도 거제시 거제중앙로 1936 (고현동)',
#   '시군구': '경상남도',
#   '시도': '거제시',
#   '타입': 'G'},
#  {'지점면': '소노캄거제  ',
#   '주소': '경상남도 거제시 일운면 거제대로 2660 1층 110호',
#   '시군구': '경상남도',
#   '시도': '거제시',
#   '타입': 'G'},
#  {'지점면': '거제옥포DT  ',
#   '주소': '경상남도 거제시 거제대로 3718 (옥포동)',
#   '시군구': '경상남도',
#   '시도': '거제시',
#   '타입': 'DT'},
#  {'지점면': '거제장평  ',
#   '주소': '경상남도 거제시 장평3로 43 (장평동)',
#   '시군구': '경상남도',
#   '시도': '거제시',
#   '타입': 'G'},
#  {'지점면': '남양산IC DT  ',
#   '주소': '경상남도 양산시 동면 양산대로 532 ',
#   '시군구': '경상남도',
#   '시도': '양산시',
#   '타입': 'DT'},
#  {'지점면': '양산증산역  ',
#   '주소': '경상남도 양산시 물금읍 증산역로 177 ',
#   '시군구': '경상남도',
#   '시도': '양산시',
#   '타입': 'G'},
#  {'지점면': '양산가촌  ',
#   '주소': '경상남도 양산시 물금읍 야리로 25 ',
#   '시군구': '경상남도',
#   '시도': '양산시',
#   '타입': 'G'},
#  {'지점면': '양산덕계DT  ',
#   '주소': '경상남도 양산시 웅상대로 860 (덕계동)',
#   '시군구': '경상남도',
#   '시도': '양산시',
#   '타입': 'DT'},
#  {'지점면': '양산터미널  ',
#   '주소': '경상남도 양산시 양산역1길 7 (중부동) 양산시외버스터미널',
#   '시군구': '경상남도',
#   '시도': '양산시',
#   '타입': 'G'},
#  {'지점면': '양산범어  ',
#   '주소': '경상남도 양산시 물금읍 범어로 62',
#   '시군구': '경상남도',
#   '시도': '양산시',
#   '타입': 'G'},
#  {'지점면': '양산이마트  ',
#   '주소': '경상남도 양산시 양산역6길 12, 양산이마트 1층 (중부동)',
#   '시군구': '경상남도',
#   '시도': '양산시',
#   '타입': 'G'},
#  {'지점면': '양산물금DT  ',
#   '주소': '경상남도 양산시 물금읍 황산로 346 ',
#   '시군구': '경상남도',
#   '시도': '양산시',
#   '타입': 'DT'},
#  {'지점면': '경산중방DT  ',
#   '주소': '경상북도 경산시 경안로 222 (중방동)',
#   '시군구': '경상북도',
#   '시도': '경산시',
#   '타입': 'DT'},
#  {'지점면': '영남대아트센터  ',
#   '주소': '경상북도 경산시 대학로 280 (대동) 영남대학교',
#   '시군구': '경상북도',
#   '시도': '경산시',
#   '타입': 'G'},
#  {'지점면': '영남대중앙도서관  ',
#   '주소': '경상북도 경산시 대학로 280 (조영동) 영남대학교',
#   '시군구': '경상북도',
#   '시도': '경산시',
#   '타입': 'G'},
#  {'지점면': '영남대  ',
#   '주소': '경상북도 경산시 청운로 16, 1~3층 (대동)',
#   '시군구': '경상북도',
#   '시도': '경산시',
#   '타입': 'G'},
#  {'지점면': '대구가톨릭대  ',
#   '주소': '경상북도 경산시 하양읍 하양로 18 ',
#   '시군구': '경상북도',
#   '시도': '경산시',
#   '타입': 'G'},
#  {'지점면': '경산이마트  ',
#   '주소': '경상북도 경산시 옥산로 227 (중산동) 경산이마트',
#   '시군구': '경상북도',
#   '시도': '경산시',
#   '타입': 'G'},
#  {'지점면': '대구대학교  ',
#   '주소': '경상북도 경산시 진량읍 대구대로 201 ',
#   '시군구': '경상북도',
#   '시도': '경산시',
#   '타입': 'G'},
#  {'지점면': '경산임당역DT  ',
#   '주소': '경상북도 경산시 대학로 208 (계양동)',
#   '시군구': '경상북도',
#   '시도': '경산시',
#   '타입': 'DT'},
#  {'지점면': '경산중산  ',
#   '주소': '경상북도 경산시 펜타힐즈로 74 (중산동) 109호,110호,111호,112호',
#   '시군구': '경상북도',
#   '시도': '경산시',
#   '타입': 'G'},
#  {'지점면': '경산하양DT  ',
#   '주소': '경상북도 경산시 진량읍 대학로 1417 ',
#   '시군구': '경상북도',
#   '시도': '경산시',
#   '타입': 'DT'},
#  {'지점면': '경산무학  ',
#   '주소': '경상북도 경산시 하양읍 서사도리9로 21 ',
#   '시군구': '경상북도',
#   '시도': '경산시',
#   '타입': 'G'},
#  {'지점면': '경주보문  ',
#   '주소': '경상북도 경주시 보문로 537 (천군동)',
#   '시군구': '경상북도',
#   '시도': '경주시',
#   '타입': 'G'},
#  {'지점면': '경주터미널DT  ',
#   '주소': '경상북도 경주시 태종로 686 (사정동)',
#   '시군구': '경상북도',
#   '시도': '경주시',
#   '타입': 'DT'},
#  {'지점면': '경주대릉원  ',
#   '주소': '경상북도 경주시 첨성로 125 (황남동)',
#   '시군구': '경상북도',
#   '시도': '경주시',
#   '타입': 'G'},
#  {'지점면': '경주보문호수DT  ',
#   '주소': '경상북도 경주시 보문로 132-6 (북군동)',
#   '시군구': '경상북도',
#   '시도': '경주시',
#   '타입': 'DT'},
#  {'지점면': '경주중앙  ',
#   '주소': '경상북도 경주시 원효로 105-1 (노동동)',
#   '시군구': '경상북도',
#   '시도': '경주시',
#   '타입': 'G'},
#  {'지점면': '경주보문로DT  ',
#   '주소': '경상북도 경주시 보문로 510-6, 외 1번지(신평동 719-220) (천군동)',
#   '시군구': '경상북도',
#   '시도': '경주시',
#   '타입': 'DT'},
#  {'지점면': '경주용강DT  ',
#   '주소': '경상북도 경주시 산업로 4350 (용강동)',
#   '시군구': '경상북도',
#   '시도': '경주시',
#   '타입': 'DT'},
#  {'지점면': '경주황성  ',
#   '주소': '경상북도 경주시 황성로1번길 4 (황성동)',
#   '시군구': '경상북도',
#   '시도': '경주시',
#   '타입': 'G'},
#  {'지점면': '구미상모DT  ',
#   '주소': '경상북도 구미시 금오대로 439 (상모동)',
#   '시군구': '경상북도',
#   '시도': '구미시',
#   '타입': 'DT'},
#  {'지점면': '구미도량DT  ',
#   '주소': '경상북도 구미시 야은로 312 (도량동)',
#   '시군구': '경상북도',
#   '시도': '구미시',
#   '타입': 'DT'},
#  {'지점면': '구미옥계  ',
#   '주소': '경상북도 구미시 옥계북로 20 (양포동)',
#   '시군구': '경상북도',
#   '시도': '구미시',
#   '타입': 'G'},
#  {'지점면': '구미시청DT  ',
#   '주소': '경상북도 구미시 송정대로 27 (송정동)',
#   '시군구': '경상북도',
#   '시도': '구미시',
#   '타입': 'DT'},
#  {'지점면': '구미금오산DT  ',
#   '주소': '경상북도 구미시 금오산로 205 (남통동)',
#   '시군구': '경상북도',
#   '시도': '구미시',
#   '타입': 'DT'},
#  {'지점면': '구미인동  ',
#   '주소': '경상북도 구미시 인동가산로 9-3, 노블레스타워 1층 (황상동)',
#   '시군구': '경상북도',
#   '시도': '구미시',
#   '타입': 'G'},
#  {'지점면': '구미공단  ',
#   '주소': '경상북도 구미시 1공단로 212, HALLA SIGMA VALLEY 106 (공단동)',
#   '시군구': '경상북도',
#   '시도': '구미시',
#   '타입': 'G'},
#  {'지점면': '구미인의DT  ',
#   '주소': '경상북도 구미시 인동북길 149 (인의동)',
#   '시군구': '경상북도',
#   '시도': '구미시',
#   '타입': 'DT'},
#  {'지점면': '구미광평DT  ',
#   '주소': '경상북도 구미시 구미대로 188 (광평동)',
#   '시군구': '경상북도',
#   '시도': '구미시',
#   '타입': 'DT'},
#  {'지점면': '구미문성DT  ',
#   '주소': '경상북도 구미시 고아읍 들성로 207 ',
#   '시군구': '경상북도',
#   '시도': '구미시',
#   '타입': 'DT'},
#  {'지점면': '구미확장단지  ',
#   '주소': '경상북도 구미시 산동읍 신당1로4길 19 ',
#   '시군구': '경상북도',
#   '시도': '구미시',
#   '타입': 'G'},
#  {'지점면': '상주무양DT  ',
#   '주소': '경상북도 상주시 영남제일로 1683 (무양동)',
#   '시군구': '경상북도',
#   '시도': '상주시',
#   '타입': 'DT'},
#  {'지점면': '경북도청대로  ',
#   '주소': '경상북도 예천군 호명면 수변로 113 ',
#   '시군구': '경상북도',
#   '시도': '예천군',
#   '타입': 'G'},
#  {'지점면': '포항쌍용DT  ',
#   '주소': '경상북도 포항시 남구 중흥로 122 (상도동)',
#   '시군구': '경상북도',
#   '시도': '포항시 남구',
#   '타입': 'DT'},
#  {'지점면': '포항오천  ',
#   '주소': '경상북도 포항시 남구 오천읍 원동로 15',
#   '시군구': '경상북도',
#   '시도': '포항시 남구',
#   '타입': 'G'},
#  {'지점면': '포항대이  ',
#   '주소': '경상북도 포항시 남구 포스코대로 124 (대잠동)',
#   '시군구': '경상북도',
#   '시도': '포항시 남구',
#   '타입': 'G'},
#  {'지점면': '포항이마트  ',
#   '주소': '경상북도 포항시 남구 냉천로 10, 이마트 포항점 1층 (인덕동)',
#   '시군구': '경상북도',
#   '시도': '포항시 남구',
#   '타입': 'G'},
#  {'지점면': '포항시청  ',
#   '주소': '경상북도 포항시 남구 시청로 5 (대잠동)',
#   '시군구': '경상북도',
#   '시도': '포항시 남구',
#   '타입': 'G'},
#  {'지점면': '포항송도  ',
#   '주소': '경상북도 포항시 남구 송도해안길 54 (송도동)',
#   '시군구': '경상북도',
#   '시도': '포항시 남구',
#   '타입': 'G'},
#  {'지점면': '포항IC DT  ',
#   '주소': '경상북도 포항시 남구 희망대로 353 (이동)',
#   '시군구': '경상북도',
#   '시도': '포항시 남구',
#   '타입': 'DT'},
#  {'지점면': '포항세명기독병원  ',
#   '주소': '경상북도 포항시 남구 포스코대로 351 (대도동)',
#   '시군구': '경상북도',
#   '시도': '포항시 남구',
#   '타입': 'G'},
#  {'지점면': '포항포스코DT  ',
#   '주소': '경상북도 포항시 남구 동해안로6213번길 15-15 (동촌동)',
#   '시군구': '경상북도',
#   '시도': '포항시 남구',
#   '타입': 'DT'},
#  {'지점면': '문경새재  ',
#   '주소': '경상북도 문경시 문경읍 새재로 906 ',
#   '시군구': '경상북도',
#   '시도': '문경시',
#   '타입': 'G'},
#  {'지점면': '김천구미역  ',
#   '주소': '경상북도 김천시 혁신3로 26 (율곡동)',
#   '시군구': '경상북도',
#   '시도': '김천시',
#   '타입': 'G'},
#  {'지점면': '김천시청DT  ',
#   '주소': '경상북도 김천시 시청로 47 (대신동)',
#   '시군구': '경상북도',
#   '시도': '김천시',
#   '타입': 'DT'},
#  {'지점면': '김천부곡DT  ',
#   '주소': '경상북도 김천시 시민로 47 (부곡동)',
#   '시군구': '경상북도',
#   '시도': '김천시',
#   '타입': 'DT'},
#  {'지점면': '안동이마트  ',
#   '주소': '경상북도 안동시 옥동1길 2 (옥동)',
#   '시군구': '경상북도',
#   '시도': '안동시',
#   '타입': 'G'},
#  {'지점면': '안동병원  ',
#   '주소': '경상북도 안동시 앙실로 11 (수상동)',
#   '시군구': '경상북도',
#   '시도': '안동시',
#   '타입': 'G'},
#  {'지점면': '안동시청  ',
#   '주소': '경상북도 안동시 서동문로 173 (삼산동)',
#   '시군구': '경상북도',
#   '시도': '안동시',
#   '타입': 'G'},
#  {'지점면': '안동강변DT  ',
#   '주소': '경상북도 안동시 육사로 327 (법흥동)',
#   '시군구': '경상북도',
#   '시도': '안동시',
#   '타입': 'DT'},
#  {'지점면': '안동옥동  ',
#   '주소': '경상북도 안동시 광명로 166 (옥동)',
#   '시군구': '경상북도',
#   '시도': '안동시',
#   '타입': 'G'},
#  {'지점면': '영천완산DT  ',
#   '주소': '경상북도 영천시 영화로 272 (완산동)',
#   '시군구': '경상북도',
#   '시도': '영천시',
#   '타입': 'DT'},
#  {'지점면': '포항죽도DT  ',
#   '주소': '경상북도 포항시 북구 새천년대로 486 699-1 에스오일',
#   '시군구': '경상북도',
#   '시도': '포항시 북구',
#   '타입': 'DT'},
#  {'지점면': '포항장성DT  ',
#   '주소': '경상북도 포항시 북구 새천년대로 1255 (장성동)',
#   '시군구': '경상북도',
#   '시도': '포항시 북구',
#   '타입': 'DT'},
#  {'지점면': '포항양덕  ',
#   '주소': '경상북도 포항시 북구 장량로 162 (양덕동)',
#   '시군구': '경상북도',
#   '시도': '포항시 북구',
#   '타입': 'G'},
#  {'지점면': '포항중앙  ',
#   '주소': '경상북도 포항시 북구 불종로 41 (신흥동)',
#   '시군구': '경상북도',
#   '시도': '포항시 북구',
#   '타입': 'G'},
#  {'지점면': '포항영일대비치  ',
#   '주소': '경상북도 포항시 북구 삼호로 186 (항구동)',
#   '시군구': '경상북도',
#   '시도': '포항시 북구',
#   '타입': 'G'},
#  {'지점면': '포항법원DT  ',
#   '주소': '경상북도 포항시 북구 신덕로 287 (장성동)',
#   '시군구': '경상북도',
#   '시도': '포항시 북구',
#   '타입': 'DT'},
#  {'지점면': '포항화진해수욕장  ',
#   '주소': '경상북도 포항시 북구 송라면 동해대로3218번길 40 (송라면)',
#   '시군구': '경상북도',
#   '시도': '포항시 북구',
#   '타입': 'G'},
#  {'지점면': '포항중앙로DT  ',
#   '주소': '경상북도 포항시 북구 중앙로 197 (죽도동)',
#   '시군구': '경상북도',
#   '시도': '포항시 북구',
#   '타입': 'DT'},
#  {'지점면': '포항두호DT  ',
#   '주소': '경상북도 포항시 북구 새천년대로 1031 (창포동)',
#   '시군구': '경상북도',
#   '시도': '포항시 북구',
#   '타입': 'DT'},
#  {'지점면': '전남광양DT  ',
#   '주소': '전라남도 광양시 중마중앙로 143 ',
#   '시군구': '전라남도',
#   '시도': '광양시',
#   '타입': 'DT'},
#  {'지점면': '광양LF  ',
#   '주소': '전라남도 광양시 광양읍 순광로 466 ',
#   '시군구': '전라남도',
#   '시도': '광양시',
#   '타입': 'G'},
#  {'지점면': '광양마동DT  ',
#   '주소': '전라남도 광양시 백운로 1267 (마동)',
#   '시군구': '전라남도',
#   '시도': '광양시',
#   '타입': 'DT'},
#  {'지점면': '목포터미널DT  ',
#   '주소': '전라남도 목포시 영산로 495 (상동)',
#   '시군구': '전라남도',
#   '시도': '목포시',
#   '타입': 'DT'},
#  {'지점면': '목포하당  ',
#   '주소': '전라남도 목포시 백년대로 293 (상동)',
#   '시군구': '전라남도',
#   '시도': '목포시',
#   '타입': 'G'},
#  {'지점면': '목포북항DT  ',
#   '주소': '전라남도 목포시 고하대로 694 (산정동)',
#   '시군구': '전라남도',
#   '시도': '목포시',
#   '타입': 'DT'},
#  {'지점면': '목포옥암  ',
#   '주소': '전라남도 목포시 백년대로375번길 1 (옥암동)',
#   '시군구': '전라남도',
#   '시도': '목포시',
#   '타입': 'G'},
#  {'지점면': '목포평화광장  ',
#   '주소': '전라남도 목포시 미항로 137 (상동)',
#   '시군구': '전라남도',
#   '시도': '목포시',
#   '타입': 'G'},
#  {'지점면': '목포이마트  ',
#   '주소': '전라남도 목포시 옥암로 138 (옥암동)',
#   '시군구': '전라남도',
#   '시도': '목포시',
#   '타입': 'G'},
#  {'지점면': '목포용해DT  ',
#   '주소': '전라남도 목포시 대양로 133 (용해동)',
#   '시군구': '전라남도',
#   '시도': '목포시',
#   '타입': 'DT'},
#  {'지점면': '목포남악  ',
#   '주소': '전라남도 무안군 남악3로82번길 11',
#   '시군구': '전라남도',
#   '시도': '무안군',
#   '타입': 'G'},
#  {'지점면': '전남도청DT  ',
#   '주소': '전라남도 무안군 삼향읍 남악3로 54 ',
#   '시군구': '전라남도',
#   '시도': '무안군',
#   '타입': 'DT'},
#  {'지점면': '순천연향  ',
#   '주소': '전라남도 순천시 연향번영길 118 (연향동)',
#   '시군구': '전라남도',
#   '시도': '순천시',
#   '타입': 'G'},
#  {'지점면': '순천신대  ',
#   '주소': '전라남도 순천시 해룡면 향매로 99 ',
#   '시군구': '전라남도',
#   '시도': '순천시',
#   '타입': 'G'},
#  {'지점면': '순천호수공원  ',
#   '주소': '전라남도 순천시 왕지2길 17 (왕지동)',
#   '시군구': '전라남도',
#   '시도': '순천시',
#   '타입': 'G'},
#  {'지점면': '순천조례  ',
#   '주소': '전라남도 순천시 비봉2길 9 (조례동)',
#   '시군구': '전라남도',
#   '시도': '순천시',
#   '타입': 'G'},
#  {'지점면': '순천용당DT  ',
#   '주소': '전라남도 순천시 중앙로 398 (가곡동)',
#   '시군구': '전라남도',
#   '시도': '순천시',
#   '타입': 'DT'},
#  {'지점면': '순천팔마DT  ',
#   '주소': '전라남도 순천시 백강로 23 (연향동)',
#   '시군구': '전라남도',
#   '시도': '순천시',
#   '타입': 'DT'},
#  {'지점면': '순천이마트  ',
#   '주소': '전라남도 순천시 팔마로 191 (덕암동)',
#   '시군구': '전라남도',
#   '시도': '순천시',
#   '타입': 'G'},
#  {'지점면': '순천오천  ',
#   '주소': '전라남도 순천시 순천만정원로 86 (풍덕동)',
#   '시군구': '전라남도',
#   '시도': '순천시',
#   '타입': 'G'},
#  {'지점면': '여수해양공원  ',
#   '주소': '전라남도 여수시 이순신광장로 192 (종화동)',
#   '시군구': '전라남도',
#   '시도': '여수시',
#   '타입': 'G'},
#  {'지점면': '여수학동DT  ',
#   '주소': '전라남도 여수시 도원로 271 (학동)',
#   '시군구': '전라남도',
#   '시도': '여수시',
#   '타입': 'DT'},
#  {'지점면': '여수웅천  ',
#   '주소': '전라남도 여수시 예울마루로 37-53 (웅천동)',
#   '시군구': '전라남도',
#   '시도': '여수시',
#   '타입': 'G'},
#  {'지점면': '여수둔덕DT  ',
#   '주소': '전라남도 여수시 좌수영로 482 (둔덕동)',
#   '시군구': '전라남도',
#   '시도': '여수시',
#   '타입': 'DT'},
#  {'지점면': '여수여서  ',
#   '주소': '전라남도 여수시 여문1로 49 (여서동)',
#   '시군구': '전라남도',
#   '시도': '여수시',
#   '타입': 'G'},
#  {'지점면': '여수여천  ',
#   '주소': '전라남도 여수시 망마로 39 (학동)',
#   '시군구': '전라남도',
#   '시도': '여수시',
#   '타입': 'G'},
#  {'지점면': '더여수돌산DT  ',
#   '주소': '전라남도 여수시 돌산읍 돌산로 3549 ',
#   '시군구': '전라남도',
#   '시도': '여수시',
#   '타입': 'DT'},
#  {'지점면': '여수신월DT  ',
#   '주소': '전라남도 여수시 신월로 567 (신월동)',
#   '시군구': '전라남도',
#   '시도': '여수시',
#   '타입': 'DT'},
#  {'지점면': '여수마리나  ',
#   '주소': '전라남도 여수시 웅천로 134 (웅천동)',
#   '시군구': '전라남도',
#   '시도': '여수시',
#   '타입': 'G'},
#  {'지점면': '전남화순DT  ',
#   '주소': '전라남도 화순군 화순읍 서양로 478 ',
#   '시군구': '전라남도',
#   '시도': '화순군',
#   '타입': 'DT'},
#  {'지점면': '전남나주  ',
#   '주소': '전라남도 나주시 상야1길 21 (빛가람동)',
#   '시군구': '전라남도',
#   '시도': '나주시',
#   '타입': 'G'},
#  {'지점면': '나주혁신DT  ',
#   '주소': '전라남도 나주시 빛가람로 838 (빛가람동)',
#   '시군구': '전라남도',
#   '시도': '나주시',
#   '타입': 'DT'},
#  {'지점면': '전북김제DT  ',
#   '주소': '전라북도 김제시 콩쥐팥쥐로 11 (검산동)',
#   '시군구': '전라북도',
#   '시도': '김제시',
#   '타입': 'DT'},
#  {'지점면': '전북남원DT  ',
#   '주소': '전라북도 남원시 요천로 1477 (쌍교동)',
#   '시군구': '전라북도',
#   '시도': '남원시',
#   '타입': 'DT'},
#  {'지점면': '익산모현  ',
#   '주소': '전라북도 익산시 선화로 106 (모현동1가)',
#   '시군구': '전라북도',
#   '시도': '익산시',
#   '타입': 'G'},
#  {'지점면': '익산영등DT  ',
#   '주소': '전라북도 익산시 무왕로 1005 (영등동)',
#   '시군구': '전라북도',
#   '시도': '익산시',
#   '타입': 'DT'},
#  {'지점면': '익산영등  ',
#   '주소': '전라북도 익산시 무왕로 1052 (영등동)',
#   '시군구': '전라북도',
#   '시도': '익산시',
#   '타입': 'G'},
#  {'지점면': '익산어양  ',
#   '주소': '전라북도 익산시 하나로 495 (영등동)',
#   '시군구': '전라북도',
#   '시도': '익산시',
#   '타입': 'G'},
#  {'지점면': '익산동산DT  ',
#   '주소': '전라북도 익산시 평동로 722 (동산동)',
#   '시군구': '전라북도',
#   '시도': '익산시',
#   '타입': 'DT'},
#  {'지점면': '전주송천DT  ',
#   '주소': '전라북도 전주시 덕진구 송천중앙로 228 (송천동2가)',
#   '시군구': '전라북도',
#   '시도': '전주시 덕진구',
#   '타입': 'DT'},
#  {'지점면': '전북대병원DT  ',
#   '주소': '전라북도 전주시 덕진구 백제대로 616 (금암동)',
#   '시군구': '전라북도',
#   '시도': '전주시 덕진구',
#   '타입': 'DT'},
#  {'지점면': '전주혁신도시  ',
#   '주소': '전라북도 전주시 덕진구 기지로 68 (중동)',
#   '시군구': '전라북도',
#   '시도': '전주시 덕진구',
#   '타입': 'G'},
#  {'지점면': '전주덕진광장DT  ',
#   '주소': '전라북도 전주시 덕진구 기린대로 491 (덕진동1가)',
#   '시군구': '전라북도',
#   '시도': '전주시 덕진구',
#   '타입': 'DT'},
#  {'지점면': '전북대  ',
#   '주소': '전라북도 전주시 덕진구 명륜4길 12 (덕진동1가)',
#   '시군구': '전라북도',
#   '시도': '전주시 덕진구',
#   '타입': 'G'},
#  {'지점면': '전주에코DT  ',
#   '주소': '전라북도 전주시 덕진구 백석로 170 (전미동1가)',
#   '시군구': '전라북도',
#   '시도': '전주시 덕진구',
#   '타입': 'DT'},
#  {'지점면': '전주에코시티  ',
#   '주소': '전라북도 전주시 덕진구 세병2길 10 (송천동2가)',
#   '시군구': '전라북도',
#   '시도': '전주시 덕진구',
#   '타입': 'G'},
#  {'지점면': '전주인후DT  ',
#   '주소': '전라북도 전주시 덕진구 아중로 135 (인후동1가)',
#   '시군구': '전라북도',
#   '시도': '전주시 덕진구',
#   '타입': 'DT'},
#  {'지점면': '전주호성DT  ',
#   '주소': '전라북도 전주시 덕진구 동부대로 860 (호성동1가)',
#   '시군구': '전라북도',
#   '시도': '전주시 덕진구',
#   '타입': 'DT'},
#  {'지점면': '전주만성DT  ',
#   '주소': '전라북도 전주시 덕진구 정여립로 972 (만성동)',
#   '시군구': '전라북도',
#   '시도': '전주시 덕진구',
#   '타입': 'DT'},
#  {'지점면': '전주IC DT  ',
#   '주소': '전라북도 전주시 덕진구 기린대로 1022 (여의동)',
#   '시군구': '전라북도',
#   '시도': '전주시 덕진구',
#   '타입': 'DT'},
#  {'지점면': '전주시청  ',
#   '주소': '전라북도 전주시 완산구 기린대로 213 (서노송동)',
#   '시군구': '전라북도',
#   '시도': '전주시 완산구',
#   '타입': 'G'},
#  {'지점면': '전주평화DT  ',
#   '주소': '전라북도 전주시 완산구 모악로 4696 (평화동2가)',
#   '시군구': '전라북도',
#   '시도': '전주시 완산구',
#   '타입': 'DT'},
#  {'지점면': '전주백제대로DT  ',
#   '주소': '전라북도 전주시 완산구 백제대로 242 (중화산동2가)',
#   '시군구': '전라북도',
#   '시도': '전주시 완산구',
#   '타입': 'DT'},
#  {'지점면': '전주효자DT  ',
#   '주소': '전라북도 전주시 완산구 용머리로 7 (효자동1가)',
#   '시군구': '전라북도',
#   '시도': '전주시 완산구',
#   '타입': 'DT'},
#  {'지점면': '전주서신  ',
#   '주소': '전라북도 전주시 완산구 서신로 104 (서신동)',
#   '시군구': '전라북도',
#   '시도': '전주시 완산구',
#   '타입': 'G'},
#  {'지점면': '전주홍산로  ',
#   '주소': '전라북도 전주시 완산구 홍산로 238 (효자동2가)',
#   '시군구': '전라북도',
#   '시도': '전주시 완산구',
#   '타입': 'G'},
#  {'지점면': '전주한옥마을  ',
#   '주소': '전라북도 전주시 완산구 팔달로 123 (전동)',
#   '시군구': '전라북도',
#   '시도': '전주시 완산구',
#   '타입': 'R'},
#  {'지점면': '전북도청  ',
#   '주소': '전라북도 전주시 완산구 홍산중앙로 22 (효자동3가)',
#   '시군구': '전라북도',
#   '시도': '전주시 완산구',
#   '타입': 'G'},
#  {'지점면': '전주경원  ',
#   '주소': '전라북도 전주시 완산구 전주객사4길 44-18 (고사동)',
#   '시군구': '전라북도',
#   '시도': '전주시 완산구',
#   '타입': 'G'},
#  {'지점면': '전주신시가지  ',
#   '주소': '전라북도 전주시 완산구 우전로 255 (효자동2가)',
#   '시군구': '전라북도',
#   '시도': '전주시 완산구',
#   '타입': 'G'},
#  {'지점면': '전주이마트  ',
#   '주소': '전라북도 전주시 완산구 당산로 111 (서신동)',
#   '시군구': '전라북도',
#   '시도': '전주시 완산구',
#   '타입': 'G'},
#  {'지점면': '전주효천DT  ',
#   '주소': '전라북도 전주시 완산구 천잠로 149 (효자동2가)',
#   '시군구': '전라북도',
#   '시도': '전주시 완산구',
#   '타입': 'DT'},
#  {'지점면': '전북정읍DT  ',
#   '주소': '전라북도 정읍시 충정로 271 (수성동)',
#   '시군구': '전라북도',
#   '시도': '정읍시',
#   '타입': 'DT'},
#  {'지점면': '군산나운DT  ',
#   '주소': '전라북도 군산시 하나운안2길 4 (나운동)',
#   '시군구': '전라북도',
#   '시도': '군산시',
#   '타입': 'DT'},
#  {'지점면': '군산수송  ',
#   '주소': '전라북도 군산시 수송로 195 (수송동)',
#   '시군구': '전라북도',
#   '시도': '군산시',
#   '타입': 'G'},
#  {'지점면': '군산대  ',
#   '주소': '전라북도 군산시 황룡로 7 (미룡동)',
#   '시군구': '전라북도',
#   '시도': '군산시',
#   '타입': 'G'},
#  {'지점면': '군산이마트  ',
#   '주소': '전라북도 군산시 구암3.1로 137 (경암동)',
#   '시군구': '전라북도',
#   '시도': '군산시',
#   '타입': 'G'},
#  {'지점면': '군산조촌DT  ',
#   '주소': '전라북도 군산시 번영로 133 (조촌동)',
#   '시군구': '전라북도',
#   '시도': '군산시',
#   '타입': 'DT'},
#  {'지점면': '군산수송DT  ',
#   '주소': '전라북도 군산시 공단대로 243 (수송동)',
#   '시군구': '전라북도',
#   '시도': '군산시',
#   '타입': 'DT'},
#  {'지점면': '공주동학사DT  ',
#   '주소': '충청남도 공주시 반포면 동학사1로 114 ',
#   '시군구': '충청남도',
#   '시도': '공주시',
#   '타입': 'DT'},
#  {'지점면': '공주신관  ',
#   '주소': '충청남도 공주시 번영1로 113 (신관동)',
#   '시군구': '충청남도',
#   '시도': '공주시',
#   '타입': 'G'},
#  {'지점면': '공주DT  ',
#   '주소': '충청남도 공주시 무령로 467 (신관동)',
#   '시군구': '충청남도',
#   '시도': '공주시',
#   '타입': 'DT'},
#  {'지점면': '논산중앙  ',
#   '주소': '충청남도 논산시 중앙로398번길 13-10',
#   '시군구': '충청남도',
#   '시도': '논산시',
#   '타입': 'G'},
#  {'지점면': '논산내동DT  ',
#   '주소': '충청남도 논산시 시민로 165 (내동)',
#   '시군구': '충청남도',
#   '시도': '논산시',
#   '타입': 'DT'},
#  {'지점면': '충남보령DT  ',
#   '주소': '충청남도 보령시 대해로 101 (궁촌동)',
#   '시군구': '충청남도',
#   '시도': '보령시',
#   '타입': 'DT'},
#  {'지점면': '대천해수욕장  ',
#   '주소': '충청남도 보령시 머드로 114 (신흑동)',
#   '시군구': '충청남도',
#   '시도': '보령시',
#   '타입': 'WT'},
#  {'지점면': '서산예천DT  ',
#   '주소': '충청남도 서산시 나무장1길 22 (예천동)',
#   '시군구': '충청남도',
#   '시도': '서산시',
#   '타입': 'DT'},
#  {'지점면': '서산호수  ',
#   '주소': '충청남도 서산시 호수공원2로 33, 1~2층 (읍내동)',
#   '시군구': '충청남도',
#   '시도': '서산시',
#   '타입': 'G'},
#  {'지점면': '서산석남DT  ',
#   '주소': '충청남도 서산시 남부순환로 994 (석남동)',
#   '시군구': '충청남도',
#   '시도': '서산시',
#   '타입': 'DT'},
#  {'지점면': '천안신부  ',
#   '주소': '충청남도 천안시 동남구 만남로 43 (신부동) 아라리오갤러리',
#   '시군구': '충청남도',
#   '시도': '천안시 동남구',
#   '타입': 'G'},
#  {'지점면': '천안청당  ',
#   '주소': '충청남도 천안시 동남구 청수14로 102 (청당동)',
#   '시군구': '충청남도',
#   '시도': '천안시 동남구',
#   '타입': 'G'},
#  {'지점면': '천안안서  ',
#   '주소': '충청남도 천안시 동남구 안서3길 3 (안서동)',
#   '시군구': '충청남도',
#   '시도': '천안시 동남구',
#   '타입': 'G'},
#  {'지점면': '천안IC DT  ',
#   '주소': '충청남도 천안시 동남구 신부15길 3 (신부동)',
#   '시군구': '충청남도',
#   '시도': '천안시 동남구',
#   '타입': 'DT'},
#  {'지점면': '천안원성DT  ',
#   '주소': '충청남도 천안시 동남구 충절로 168 (원성동)',
#   '시군구': '충청남도',
#   '시도': '천안시 동남구',
#   '타입': 'DT'},
#  {'지점면': '신세계천안아산  ',
#   '주소': '충청남도 천안시 동남구 만남로 43 (신부동) B관 4층',
#   '시군구': '충청남도',
#   '시도': '천안시 동남구',
#   '타입': 'G'},
#  {'지점면': '천안청당신도시  ',
#   '주소': '충청남도 천안시 동남구 남부대로 322 1동 1층',
#   '시군구': '충청남도',
#   '시도': '천안시 동남구',
#   '타입': 'G'},
#  {'지점면': '천안대로DT  ',
#   '주소': '충청남도 천안시 동남구 천안대로 527 (구성동)',
#   '시군구': '충청남도',
#   '시도': '천안시 동남구',
#   '타입': 'DT'},
#  {'지점면': '천안서북이마트  ',
#   '주소': '충청남도 천안시 서북구 삼성대로 20 (백석동)',
#   '시군구': '충청남도',
#   '시도': '천안시 서북구',
#   '타입': 'G'},
#  {'지점면': '천안백석  ',
#   '주소': '충청남도 천안시 서북구 백석로 85-4 (백석동)',
#   '시군구': '충청남도',
#   '시도': '천안시 서북구',
#   '타입': 'G'},
#  {'지점면': '천안불당DT  ',
#   '주소': '충청남도 천안시 서북구 불당34길 4 (불당동)',
#   '시군구': '충청남도',
#   '시도': '천안시 서북구',
#   '타입': 'DT'},
#  {'지점면': '천안서부대로DT  ',
#   '주소': '충청남도 천안시 서북구 서부대로 405 (쌍용동)',
#   '시군구': '충청남도',
#   '시도': '천안시 서북구',
#   '타입': 'DT'},
#  {'지점면': '천안두정역DT  ',
#   '주소': '충청남도 천안시 서북구 두정로 264 (두정동)',
#   '시군구': '충청남도',
#   '시도': '천안시 서북구',
#   '타입': 'DT'},
#  {'지점면': '천안시청  ',
#   '주소': '충청남도 천안시 서북구 불당22대로 67 (불당동)',
#   '시군구': '충청남도',
#   '시도': '천안시 서북구',
#   '타입': 'G'},
#  {'지점면': '천안쌍용역  ',
#   '주소': '충청남도 천안시 서북구 충무로 133 (쌍용동)',
#   '시군구': '충청남도',
#   '시도': '천안시 서북구',
#   '타입': 'G'},
#  {'지점면': '천안신불당  ',
#   '주소': '충청남도 천안시 서북구 불당33길 24 (불당동)',
#   '시군구': '충청남도',
#   '시도': '천안시 서북구',
#   '타입': 'G'},
#  {'지점면': '천안성정DT  ',
#   '주소': '충청남도 천안시 서북구 동서대로 154 (성정동)',
#   '시군구': '충청남도',
#   '시도': '천안시 서북구',
#   '타입': 'DT'},
#  {'지점면': '천안불당  ',
#   '주소': '충청남도 천안시 서북구 불당4로 91 (불당동)',
#   '시군구': '충청남도',
#   '시도': '천안시 서북구',
#   '타입': 'G'},
#  {'지점면': '천안두정  ',
#   '주소': '충청남도 천안시 서북구 부성4길 3 (부성1동)',
#   '시군구': '충청남도',
#   '시도': '천안시 서북구',
#   '타입': 'G'},
#  {'지점면': '천안이마트  ',
#   '주소': '충청남도 천안시 서북구 충무로 187 (쌍용동) 천안이마트 1층',
#   '시군구': '충청남도',
#   '시도': '천안시 서북구',
#   '타입': 'G'},
#  {'지점면': '천안불당신도시  ',
#   '주소': '충청남도 천안시 서북구 불당23로 73-27 (불당동)',
#   '시군구': '충청남도',
#   '시도': '천안시 서북구',
#   '타입': 'G'},
#  {'지점면': '천안업성레이크  ',
#   '주소': '충청남도 천안시 서북구 업성수변로 69 (성성동)',
#   '시군구': '충청남도',
#   '시도': '천안시 서북구',
#   '타입': 'G'},
#  {'지점면': '충남홍성DT  ',
#   '주소': '충청남도 홍성군 홍성읍 도청대로 58 ',
#   '시군구': '충청남도',
#   '시도': '홍성군',
#   '타입': 'DT'},
#  {'지점면': '충남도청  ',
#   '주소': '충청남도 홍성군 홍북읍 청사로150번길 24 ',
#   '시군구': '충청남도',
#   '시도': '홍성군',
#   '타입': 'G'},
#  {'지점면': '계룡대로DT  ',
#   '주소': '충청남도 계룡시 엄사면 번영로 6 ',
#   '시군구': '충청남도',
#   '시도': '계룡시',
#   '타입': 'DT'},
#  {'지점면': '계룡대실DT  ',
#   '주소': '충청남도 계룡시 계룡대로 239 (금암동)',
#   '시군구': '충청남도',
#   '시도': '계룡시',
#   '타입': 'DT'},
#  {'지점면': '당진시곡DT  ',
#   '주소': '충청남도 당진시 서해로 6283 (시곡동)',
#   '시군구': '충청남도',
#   '시도': '당진시',
#   '타입': 'DT'},
#  {'지점면': '당진문예의전당  ',
#   '주소': '충청남도 당진시 시청1로 78 (읍내동) 1층',
#   '시군구': '충청남도',
#   '시도': '당진시',
#   '타입': 'G'},
#  {'지점면': '아산방축DT  ',
#   '주소': '충청남도 아산시 온천대로 1392 (방축동)',
#   '시군구': '충청남도',
#   '시도': '아산시',
#   '타입': 'DT'},
#  {'지점면': '아산배방  ',
#   '주소': '충청남도 아산시 배방읍 배방로 22 ',
#   '시군구': '충청남도',
#   '시도': '아산시',
#   '타입': 'G'},
#  {'지점면': '아산탕정  ',
#   '주소': '충청남도 아산시 탕정면 탕정면로 10 ',
#   '시군구': '충청남도',
#   '시도': '아산시',
#   '타입': 'G'},
#  {'지점면': '아산용화  ',
#   '주소': '충청남도 아산시 어의정로 117 (용화동)',
#   '시군구': '충청남도',
#   '시도': '아산시',
#   '타입': 'G'},
#  {'지점면': '아산터미널  ',
#   '주소': '충청남도 아산시 번영로 232 (모종동)',
#   '시군구': '충청남도',
#   '시도': '아산시',
#   '타입': 'G'},
#  {'지점면': '아산권곡  ',
#   '주소': '충청남도 아산시 문화로 271-6 (권곡동) 101~105호',
#   '시군구': '충청남도',
#   '시도': '아산시',
#   '타입': 'G'},
#  {'지점면': '아산탕정역  ',
#   '주소': '충청남도 아산시 탕정면 한들물빛도시로 88 거산타워 104,105,106,107,111호',
#   '시군구': '충청남도',
#   '시도': '아산시',
#   '타입': 'G'},
#  {'지점면': '아산모종  ',
#   '주소': '충청남도 아산시 온천대로 1721 (모종동) 아산축산농협 1층',
#   '시군구': '충청남도',
#   '시도': '아산시',
#   '타입': 'G'},
#  {'지점면': '천안아산역  ',
#   '주소': '충청남도 아산시 배방읍 고속철대로 147 101~105호',
#   '시군구': '충청남도',
#   '시도': '아산시',
#   '타입': 'G'},
#  {'지점면': '충북증평  ',
#   '주소': '충청북도 증평군 증평읍 광장로 40 ',
#   '시군구': '충청북도',
#   '시도': '증평군',
#   '타입': 'G'},
#  {'지점면': '청주용암DT  ',
#   '주소': '충청북도 청주시 상당구 1순환로 1243 (용암동)',
#   '시군구': '충청북도',
#   '시도': '청주시 상당구',
#   '타입': 'DT'},
#  {'지점면': '청주용담DT  ',
#   '주소': '충청북도 청주시 상당구 산성로 129 (용담동)',
#   '시군구': '충청북도',
#   '시도': '청주시 상당구',
#   '타입': 'DT'},
#  {'지점면': '청주서문  ',
#   '주소': '충청북도 청주시 상당구 무심동로392번길 20 (서문동)',
#   '시군구': '충청북도',
#   '시도': '청주시 상당구',
#   '타입': 'G'},
#  {'지점면': '충북도청  ',
#   '주소': '충청북도 청주시 상당구 상당로 66 (문화동)',
#   '시군구': '충청북도',
#   '시도': '청주시 상당구',
#   '타입': 'G'},
#  {'지점면': '청주동남  ',
#   '주소': '충청북도 청주시 상당구 중고개로141번길 13-16 (용암동)',
#   '시군구': '충청북도',
#   '시도': '청주시 상당구',
#   '타입': 'G'},
#  {'지점면': '충주호암DT  ',
#   '주소': '충청북도 충주시 중원대로 3245 (호암동)',
#   '시군구': '충청북도',
#   '시도': '충주시',
#   '타입': 'DT'},
#  {'지점면': '충주시청DT  ',
#   '주소': '충청북도 충주시 국원대로 208-1 (금릉동)',
#   '시군구': '충청북도',
#   '시도': '충주시',
#   '타입': 'DT'},
#  {'지점면': '충주터미널  ',
#   '주소': '충청북도 충주시 봉계13길 2 (봉방동)',
#   '시군구': '충청북도',
#   '시도': '충주시',
#   '타입': 'G'},
#  {'지점면': '충주연수  ',
#   '주소': '충청북도 충주시 계명대로 227 (연수동)',
#   '시군구': '충청북도',
#   '시도': '충주시',
#   '타입': 'G'},
#  {'지점면': '충주교현DT  ',
#   '주소': '충청북도 충주시 금봉대로 358 (교현동)',
#   '시군구': '충청북도',
#   '시도': '충주시',
#   '타입': 'DT'},
#  {'지점면': '충북혁신도시  ',
#   '주소': '충청북도 음성군 맹동면 원중로 1416 ',
#   '시군구': '충청북도',
#   '시도': '음성군',
#   '타입': 'G'},
#  {'지점면': '제천DT  ',
#   '주소': '충청북도 제천시 의림대로 181 (중앙로2가)',
#   '시군구': '충청북도',
#   '시도': '제천시',
#   '타입': 'DT'},
#  {'지점면': '제천하소DT  ',
#   '주소': '충청북도 제천시 용두대로 55 (하소동)',
#   '시군구': '충청북도',
#   '시도': '제천시',
#   '타입': 'DT'},
#  {'지점면': '청주비하DT  ',
#   '주소': '충청북도 청주시 흥덕구 2순환로 1078 (비하동)',
#   '시군구': '충청북도',
#   '시도': '청주시 흥덕구',
#   '타입': 'DT'},
#  {'지점면': '청주오송  ',
#   '주소': '충청북도 청주시 흥덕구 오송읍 오송생명로 220 ',
#   '시군구': '충청북도',
#   '시도': '청주시 흥덕구',
#   '타입': 'G'},
#  {'지점면': '청주봉명DT  ',
#   '주소': '충청북도 청주시 흥덕구 1순환로 514 (봉명동)',
#   '시군구': '충청북도',
#   '시도': '청주시 흥덕구',
#   '타입': 'DT'},
#  {'지점면': '청주강서  ',
#   '주소': '충청북도 청주시 흥덕구 강서로 121 (강서동)',
#   '시군구': '충청북도',
#   '시도': '청주시 흥덕구',
#   '타입': 'G'},
#  {'지점면': '청주지웰시티  ',
#   '주소': '충청북도 청주시 흥덕구 대농로 43 (복대동) 신영지웰시티 1차 상업시설',
#   '시군구': '충청북도',
#   '시도': '청주시 흥덕구',
#   '타입': 'G'},
#  {'지점면': '현대충청  ',
#   '주소': '충청북도 청주시 흥덕구 직지대로 308 (복대동)',
#   '시군구': '충청북도',
#   '시도': '청주시 흥덕구',
#   '타입': 'G'},
#  {'지점면': '청주터미널  ',
#   '주소': '충청북도 청주시 흥덕구 풍산로 15 (가경동)',
#   '시군구': '충청북도',
#   '시도': '청주시 흥덕구',
#   '타입': 'G'},
#  {'지점면': '오송바이오산업단지  ',
#   '주소': '충청북도 청주시 흥덕구 오송읍 오송생명로 159 오송생명로 159',
#   '시군구': '충청북도',
#   '시도': '청주시 흥덕구',
#   '타입': 'G'},
#  {'지점면': '청주서현  ',
#   '주소': '충청북도 청주시 흥덕구 서현로 60 (가경동) 121호,122호,123호,124호',
#   '시군구': '충청북도',
#   '시도': '청주시 흥덕구',
#   '타입': 'G'},
#  {'지점면': '청주복대지웰  ',
#   '주소': '충청북도 청주시 흥덕구 대농로 52 (복대동)',
#   '시군구': '충청북도',
#   '시도': '청주시 흥덕구',
#   '타입': 'G'},
#  {'지점면': '청주이마트  ',
#   '주소': '충청북도 청주시 서원구 청남로 1853 (미평동)',
#   '시군구': '충청북도',
#   '시도': '청주시 서원구',
#   '타입': 'G'},
#  {'지점면': '청주사직DT  ',
#   '주소': '충청북도 청주시 서원구 사직대로 302 (사직동)',
#   '시군구': '충청북도',
#   '시도': '청주시 서원구',
#   '타입': 'DT'},
#  {'지점면': '청주성화  ',
#   '주소': '충청북도 청주시 서원구 복대로 5 (개신동)',
#   '시군구': '충청북도',
#   '시도': '청주시 서원구',
#   '타입': 'G'},
#  {'지점면': '충북대  ',
#   '주소': '충청북도 청주시 서원구 내수동로 113 (사창동)',
#   '시군구': '충청북도',
#   '시도': '청주시 서원구',
#   '타입': 'G'},
#  {'지점면': '청주분평DT  ',
#   '주소': '충청북도 청주시 서원구 1순환로 1154 (분평동)',
#   '시군구': '충청북도',
#   '시도': '청주시 서원구',
#   '타입': 'DT'},
#  {'지점면': '오창호수공원  ',
#   '주소': '충청북도 청주시 청원구 오창읍 중심상업1로 20 101,102,103,104호',
#   '시군구': '충청북도',
#   '시도': '청주시 청원구',
#   '타입': 'G'},
#  {'지점면': '청주율량DT  ',
#   '주소': '충청북도 청주시 청원구 충청대로107번길 8 (율량동)',
#   '시군구': '충청북도',
#   '시도': '청주시 청원구',
#   '타입': 'DT'},
#  {'지점면': '오창과학단지  ',
#   '주소': '충청북도 청주시 청원구 오창읍 과학산업2로 385 ',
#   '시군구': '충청북도',
#   '시도': '청주시 청원구',
#   '타입': 'G'},
#  {'지점면': '청주주성  ',
#   '주소': '충청북도 청주시 청원구 주성로279번길 27-19 (주성동)',
#   '시군구': '충청북도',
#   '시도': '청주시 청원구',
#   '타입': 'G'},
#  {'지점면': '충북혁신덕산  ',
#   '주소': '충청북도 진천군 덕산읍 연미1길 11 ',
#   '시군구': '충청북도',
#   '시도': '진천군',
#   '타입': 'G'},
#  {'지점면': '제주신화월드R  ',
#   '주소': '제주특별자치도 서귀포시 안덕면 신화역사로304번길 38 B1-29',
#   '시군구': '제주특별자치도',
#   '시도': '서귀포시',
#   '타입': 'R'},
#  {'지점면': '제주에듀시티  ',
#   '주소': '제주특별자치도 서귀포시 대정읍 에듀시티로 36 ',
#   '시군구': '제주특별자치도',
#   '시도': '서귀포시',
#   '타입': 'G'},
#  {'지점면': '제주성산DT  ',
#   '주소': '제주특별자치도 서귀포시 성산읍 일출로 80 ',
#   '시군구': '제주특별자치도',
#   '시도': '서귀포시',
#   '타입': 'DT'},
#  {'지점면': '제주중문DT  ',
#   '주소': '제주특별자치도 서귀포시 천제연로 95(색달동)',
#   '시군구': '제주특별자치도',
#   '시도': '서귀포시',
#   '타입': 'DT'},
#  {'지점면': '제주송악산  ',
#   '주소': '제주특별자치도 서귀포시 대정읍 형제해안로 322',
#   '시군구': '제주특별자치도',
#   '시도': '서귀포시',
#   '타입': 'G'},
#  {'지점면': '서귀포DT  ',
#   '주소': '제주특별자치도 서귀포시 일주서로 11 (강정동)',
#   '시군구': '제주특별자치도',
#   '시도': '서귀포시',
#   '타입': 'DT'},
#  {'지점면': '성산일출봉  ',
#   '주소': '제주특별자치도 서귀포시 성산읍 일출로 284-5 1,2층',
#   '시군구': '제주특별자치도',
#   '시도': '서귀포시',
#   '타입': 'G'},
#  {'지점면': '제주중문  ',
#   '주소': '제주특별자치도 서귀포시 중문관광로110번길 32 (색달동)',
#   '시군구': '제주특별자치도',
#   '시도': '서귀포시',
#   '타입': 'G'},
#  {'지점면': '서귀포올레  ',
#   '주소': '제주특별자치도 서귀포시 중정로 69 (서귀동)',
#   '시군구': '제주특별자치도',
#   '시도': '서귀포시',
#   '타입': 'G'},
#  {'지점면': '제주서귀포남원DT  ',
#   '주소': '제주특별자치도 서귀포시 남원읍 일주동로 7129 ',
#   '시군구': '제주특별자치도',
#   '시도': '서귀포시',
#   '타입': 'DT'},
#  {'지점면': '제주도남DT  ',
#   '주소': '제주특별자치도 제주시 연북로 394 (도남동)',
#   '시군구': '제주특별자치도',
#   '시도': '제주시',
#   '타입': 'DT'},
#  {'지점면': '제주협재  ',
#   '주소': '제주특별자치도 제주시 한림읍 한림로 337 ',
#   '시군구': '제주특별자치도',
#   '시도': '제주시',
#   '타입': 'G'},
#  {'지점면': '제주외도DT  ',
#   '주소': '제주특별자치도 제주시 일주서로 7300 (외도일동)',
#   '시군구': '제주특별자치도',
#   '시도': '제주시',
#   '타입': 'DT'},
#  {'지점면': '제주삼화DT  ',
#   '주소': '제주특별자치도 제주시 연삼로 884 (도련일동)',
#   '시군구': '제주특별자치도',
#   '시도': '제주시',
#   '타입': 'DT'},
#  {'지점면': '제주시청  ',
#   '주소': '제주특별자치도 제주시 중앙로 215 (이도이동)',
#   '시군구': '제주특별자치도',
#   '시도': '제주시',
#   '타입': 'G'},
#  {'지점면': '제주함덕  ',
#   '주소': '제주특별자치도 제주시 조천읍 조함해안로 522 ',
#   '시군구': '제주특별자치도',
#   '시도': '제주시',
#   '타입': 'G'},
#  {'지점면': '제주애월DT  ',
#   '주소': '제주특별자치도 제주시 애월읍 애월해안로 376 ',
#   '시군구': '제주특별자치도',
#   '시도': '제주시',
#   '타입': 'DT'},
#  {'지점면': '제주칠성  ',
#   '주소': '제주특별자치도 제주시 관덕로 55 (일도일동)',
#   '시군구': '제주특별자치도',
#   '시도': '제주시',
#   '타입': 'G'},
#  {'지점면': '제주노형  ',
#   '주소': '제주특별자치도 제주시 도령로 27 (노형동)',
#   '시군구': '제주특별자치도',
#   '시도': '제주시',
#   '타입': 'G'},
#  {'지점면': '제주용담DT  ',
#   '주소': '제주특별자치도 제주시 서해안로 380 (용담삼동) 화이트하우스',
#   '시군구': '제주특별자치도',
#   '시도': '제주시',
#   '타입': 'DT'},
#  {'지점면': '신제주이마트  ',
#   '주소': '제주특별자치도 제주시 1100로 3348, 신제주이마트 1층 (노형동)',
#   '시군구': '제주특별자치도',
#   '시도': '제주시',
#   '타입': 'G'},
#  {'지점면': '제주세화DT  ',
#   '주소': '제주특별자치도 제주시 구좌읍 일주동로 3121 ',
#   '시군구': '제주특별자치도',
#   '시도': '제주시',
#   '타입': 'DT'},
#  {'지점면': '제주노형로  ',
#   '주소': '제주특별자치도 제주시 노형로 376 (노형동)',
#   '시군구': '제주특별자치도',
#   '시도': '제주시',
#   '타입': 'G'},
#  {'지점면': '제주노형DT  ',
#   '주소': '제주특별자치도 제주시 월랑로 68 (노형동)',
#   '시군구': '제주특별자치도',
#   '시도': '제주시',
#   '타입': 'DT'},
#  {'지점면': '제주한라수목원DT  ',
#   '주소': '제주특별자치도 제주시 수목원서길 3-5 (노형동)',
#   '시군구': '제주특별자치도',
#   '시도': '제주시',
#   '타입': 'DT'},
#  {'지점면': '제주서해안로DT  ',
#   '주소': '제주특별자치도 제주시 서해안로 624 (용담삼동)',
#   '시군구': '제주특별자치도',
#   '시도': '제주시',
#   '타입': 'DT'},
#  {'지점면': '제주일도DT  ',
#   '주소': '제주특별자치도 제주시 동광로 130 (일도이동)',
#   '시군구': '제주특별자치도',
#   '시도': '제주시',
#   '타입': 'DT'},
#  {'지점면': '제주공항DT  ',
#   '주소': '제주특별자치도 제주시 월성로 42 (용담이동)',
#   '시군구': '제주특별자치도',
#   '시도': '제주시',
#   '타입': 'DT'},
#  {'지점면': '더제주송당파크R  ',
#   '주소': '제주특별자치도 제주시 구좌읍 비자림로 1189 ',
#   '시군구': '제주특별자치도',
#   '시도': '제주시',
#   '타입': 'R'},
#  {'지점면': '제주평화로DT  ',
#   '주소': '제주특별자치도 제주시 노형로 37 (해안동)',
#   '시군구': '제주특별자치도',
#   '시도': '제주시',
#   '타입': 'DT'},
#  {'지점면': '세종다정DT  ',
#   '주소': '세종특별자치시 다정북로 219 (다정동)',
#   '시군구': '세종특별자치시',
#   '시도': '',
#   '타입': 'DT'},
#  {'지점면': '세종보람  ',
#   '주소': '세종특별자치시 한누리대로 2165 (보람동) A118,119,120,121,128,129,130,131',
#   '시군구': '세종특별자치시',
#   '시도': '',
#   '타입': 'G'},
#  {'지점면': '세종새롬  ',
#   '주소': '세종특별자치시  새롬중앙로 64 (새롬동)',
#   '시군구': '세종특별자치시',
#   '시도': '',
#   '타입': 'G'},
#  {'지점면': '세종어진R  ',
#   '주소': '세종특별자치시  한누리대로 499 (어진동)',
#   '시군구': '세종특별자치시',
#   '시도': '',
#   '타입': 'R'},
#  {'지점면': '세종종촌  ',
#   '주소': '세종특별자치시  도움3로 105-10 (종촌동) 성운프라자',
#   '시군구': '세종특별자치시',
#   '시도': '',
#   '타입': 'G'},
#  {'지점면': '세종첫마을  ',
#   '주소': '세종특별자치시  한누리대로 169 행복타워 1층',
#   '시군구': '세종특별자치시',
#   '시도': '',
#   '타입': 'G'},
#  {'지점면': '세종이마트  ',
#   '주소': '세종특별자치시 금송로 687(가람동 406) 이마트 세종점',
#   '시군구': '세종특별자치시',
#   '시도': '',
#   '타입': 'G'},
#  {'지점면': '세종청사  ',
#   '주소': '세종특별자치시  도움8로 81 (어진동)',
#   '시군구': '세종특별자치시',
#   '시도': '',
#   '타입': 'G'},
#  {'지점면': '세종아름  ',
#   '주소': '세종특별자치시 아름서1길 13-9 (아름동) 103,104,105,202,203호',
#   '시군구': '세종특별자치시',
#   '시도': '',
#   '타입': 'G'},
#  {'지점면': '세종반곡  ',
#   '주소': '세종특별자치시 한누리대로 1844 (반곡동)',
#   '시군구': '세종특별자치시',
#   '시도': '',
#   '타입': 'G'},
#  {'지점면': '세종한솔  ',
#   '주소': '세종특별자치시 노을3로 101 (한솔동)',
#   '시군구': '세종특별자치시',
#   '시도': '',
#   '타입': 'G'},
#  {'지점면': '세종소담  ',
#   '주소': '세종특별자치시 소담3로 8 (소담동) 1동  12호,13호,14호,15호,15a호,16호',
#   '시군구': '세종특별자치시',
#   '시도': '',
#   '타입': 'G'},
#  {'지점면': '세종금강DT  ',
#   '주소': '세종특별자치시 시청대로 45 (대평동)',
#   '시군구': '세종특별자치시',
#   '시도': '',
#   '타입': 'DT'},
#  {'지점면': '세종충남대학교병원  ',
#   '주소': '세종특별자치시 보듬7로 20 (도담동) 헬스케어센터 1층',
#   '시군구': '세종특별자치시',
#   '시도': '',
#   '타입': 'G'}]

# %%
# 적재된 데이터 json 형태로 저장
from datetime import datetime
import json

print(f"전체 데이터 수 : {len(DataBase)}")

with open("crawling_data_v2.json", "w") as file:
    json.dump({    "date": str(datetime.now()),
                    "description": "전국 스타벅스 매장의 데이터를 '지점명, 주소, 시군구, 시도, 타입'를 키로 갖는 데이터로 저장함",
                    "data length" : len(DataBase),
                    "data" : DataBase
                    }, file, indent=4, ensure_ascii = False)
# Out:
# 전체 데이터 수 : 1904

# %%
# pandas 데이터 프레임을 로드
import pandas as pd
columns = DataBase[0].keys()

df = pd.DataFrame(DataBase, columns = columns)
print(display(df))
print(df.info())
# Out:
#               지점면                                                 주소      시군구  \
# 0       역삼아레나빌딩                              서울특별시 강남구 언주로 425 (역삼동)    서울특별시
# 1        논현역사거리                             서울특별시 강남구 강남대로 538 (논현동)    서울특별시
# 2       신사역성일빌딩                             서울특별시 강남구 강남대로 584 (논현동)    서울특별시
# 3        국기원사거리                             서울특별시 강남구 테헤란로 125 (역삼동)    서울특별시
# 4        대치재경빌딩                           서울특별시 강남구 남부순환로 2947 (대치동)    서울특별시
# ...           ...                                                ...      ...
# 1899       세종반곡                             세종특별자치시 한누리대로 1844 (반곡동)  세종특별자치시
# 1900       세종한솔                               세종특별자치시 노을3로 101 (한솔동)  세종특별자치시
# 1901       세종소담    세종특별자치시 소담3로 8 (소담동) 1동  12호,13호,14호,15호,15a호,16호  세종특별자치시
# 1902     세종금강DT                                세종특별자치시 시청대로 45 (대평동)  세종특별자치시
# 1903  세종충남대학교병원                      세종특별자치시 보듬7로 20 (도담동) 헬스케어센터 1층  세종특별자치시
#
#        시도  타입
# 0     강남구   G
# 1     강남구   G
# 2     강남구   G
# 3     강남구   G
# 4     강남구   G
# ...   ...  ..
# 1899        G
# 1900        G
# 1901        G
# 1902       DT
# 1903        G
#
# [1904 rows x 5 columns]
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1904 entries, 0 to 1903
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지점면     1904 non-null   object
#  1   주소      1904 non-null   object
#  2   시군구     1904 non-null   object
#  3   시도      1904 non-null   object
#  4   타입      1904 non-null   object
# dtypes: object(5)
# memory usage: 74.5+ KB
# None

# %% [markdown]
# 사이트 내부 에러
#
#
# ![image.png](attachment:image.png)
#
#
# ```code
# ---------------------------------------------------------
# 대구칠곡읍내DT
# 칠곡중앙대로 631 칠곡중앙대로 631  <--- '대구광역시 북구' 주소 누락됨
# 1522-3232
# ---------------------------------------------------------
# ```
